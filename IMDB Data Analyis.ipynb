# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv(r"C:\Users\Dhanwantari Devre\VS CODE PROJECTS\Basics\EDA\EDA2\movie.csv")
movies.shape
# Out:
# (27278, 3)

# %%
ratings=pd.read_csv(r"C:\Users\Dhanwantari Devre\VS CODE PROJECTS\Basics\EDA\EDA2\rating.csv")
ratings.shape
# Out:
# (20000263, 4)

# %%
tags=pd.read_csv(r"C:\Users\Dhanwantari Devre\VS CODE PROJECTS\Basics\EDA\EDA2\tag.csv")
tags.shape
# If there is an error in the above code, it is likely due to the file paths.
# Thats why used the r for raw strings
# Out:
# (465564, 4)

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
ratings
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
del tags['timestamp']

# %%
print(tags.columns)
print(ratings.columns)
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
row_1=ratings.iloc[1]
# iloc index location
print(type(row_1))
print(row_1)
# Out:
# <class 'pandas.core.series.Series'>
# userId      1.0
# movieId    29.0
# rating      3.5
# Name: 1, dtype: float64

# %%
row_0=tags.iloc[0]
print(type(row_0))
print(row_0)
# Out:
# <class 'pandas.core.series.Series'>
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_1
# Out:
# userId      1.0
# movieId    29.0
# rating      3.5
# Name: 1, dtype: float64

# %%
row_0['userId']
# Out:
# 18

# %%
'rating' in row_0
# Out:
# False

# %%
row_0.name
# Out:
# 0

# %%
row_0=row_0.rename('firstrow')
print(row_0)
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: firstrow, dtype: object

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,500,1150]]
# Out:
#       userId  movieId                tag
# 0         18     4141        Mark Waters
# 11        65     1783      noir thriller
# 500      342    55908  entirely dialogue
# 1150     469    56093    dialogue driven

# %% [markdown]
# # Descriptive statistics

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].describe().transpose()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].describe().T
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
round(ratings.mean(),2)
# having round function to round off the mea value till 2 decimal places
# Out:
# userId     69045.87
# movieId     9041.57
# rating         3.53
# dtype: float64

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
round(ratings['rating'].mean(),2)
# Out:
# 3.53

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
round(ratings['rating'].std(),2)
# Out:
# 1.05

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr
# to find the correlation between the columns
# Out:
# <bound method DataFrame.corr of           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]>

# %%
filter1=ratings['rating']>10
print(filter1)
print(filter1.any())
# dont uderstand this one
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %%
filter2=ratings['rating']>10
print(filter2)
filter2.all()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %% [markdown]
# # Data Cleaning : handling Missing Data

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull()
# Out:
#        movieId  title  genres
# 0        False  False   False
# 1        False  False   False
# 2        False  False   False
# 3        False  False   False
# 4        False  False   False
# ...        ...    ...     ...
# 27273    False  False   False
# 27274    False  False   False
# 27275    False  False   False
# 27276    False  False   False
# 27277    False  False   False
#
# [27278 rows x 3 columns]

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
movies.isnull().any().any()
# Out:
# False

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any().any()
# Out:
# True

# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

ratings.hist(column='rating', figsize=(10,5))
plt.show()

# %%
ratings.boxplot(column='rating', figsize=(10,5))
# plt.show()
# Out:
# <Axes: >

# %% [markdown]
# # Slicing Out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='tag'>
